# %% [markdown]
# ## Import data

# %%
import pandas as pd 
import numpy as np
pd.options.display.float_format = '{:.2f}'.format
df = pd.read_csv('3d_desc.csv',index_col=0)

# %%
df.head()
# Out:
#            Name  PubChem CID  Observed logFM  Predicted logFM  \
# 0  Oxychlordane        33772           -1.02            -0.80
# 1           DDE         3035           -0.98            -0.64
# 2  Mifepristone         4196           -0.96            -0.41
# 3    Atazanavir       148192           -0.89            -0.70
# 4     Nonachlor        19520           -0.84            -1.00
#
#                                               SMILES  Asphericity  \
# 0  C12C(C(C3(C1O3)Cl)Cl)C4(C(=C(C2(C4(Cl)Cl)Cl)Cl...         0.12
# 1          C1=CC(=CC=C1C(=C(Cl)Cl)C2=CC=C(C=C2)Cl)Cl         0.36
# 2  CC#CC1(CCC2C1(CC(C3=C4CCC(=O)C=C4CCC23)C5=CC=C...         0.18
# 3  CC(C)(C)[C@@H](C(=O)N[C@@H](CC1=CC=CC=C1)[C@H]...         0.21
# 4  C12C(C(C(C1Cl)Cl)Cl)C3(C(=C(C2(C3(Cl)Cl)Cl)Cl)...         0.05
#
#    Eccentricity  InertialShapeFactor  NPR1  NPR2    PMI1     PMI2     PMI3  \
# 0          0.85                 0.00  0.53  0.84 1547.95  2465.69  2937.81
# 1          0.95                 0.00  0.30  0.74 1310.39  3209.34  4343.41
# 2          0.87                 0.00  0.49  0.64 3254.02  4267.07  6666.09
# 3          0.90                 0.00  0.43  0.70 9264.16 15031.32 21335.12
# 4          0.73                 0.00  0.68  0.82 2042.08  2465.64  3006.66
#
#    RadiusOfGyration  SpherocityIndex
# 0              2.86             0.65
# 1              3.73             0.25
# 2              4.06             0.26
# 3              5.69             0.26
# 4              2.91             0.73

# %% [markdown]
# ## Data preprocessing

# %%
df.drop(df.std()[df.std() == 0].index.values,axis=1,inplace=True)
df.head()
# Out:
#            Name  PubChem CID  Observed logFM  Predicted logFM  \
# 0  Oxychlordane        33772           -1.02            -0.80
# 1           DDE         3035           -0.98            -0.64
# 2  Mifepristone         4196           -0.96            -0.41
# 3    Atazanavir       148192           -0.89            -0.70
# 4     Nonachlor        19520           -0.84            -1.00
#
#                                               SMILES  Asphericity  \
# 0  C12C(C(C3(C1O3)Cl)Cl)C4(C(=C(C2(C4(Cl)Cl)Cl)Cl...         0.12
# 1          C1=CC(=CC=C1C(=C(Cl)Cl)C2=CC=C(C=C2)Cl)Cl         0.36
# 2  CC#CC1(CCC2C1(CC(C3=C4CCC(=O)C=C4CCC23)C5=CC=C...         0.18
# 3  CC(C)(C)[C@@H](C(=O)N[C@@H](CC1=CC=CC=C1)[C@H]...         0.21
# 4  C12C(C(C(C1Cl)Cl)Cl)C3(C(=C(C2(C3(Cl)Cl)Cl)Cl)...         0.05
#
#    Eccentricity  InertialShapeFactor  NPR1  NPR2    PMI1     PMI2     PMI3  \
# 0          0.85                 0.00  0.53  0.84 1547.95  2465.69  2937.81
# 1          0.95                 0.00  0.30  0.74 1310.39  3209.34  4343.41
# 2          0.87                 0.00  0.49  0.64 3254.02  4267.07  6666.09
# 3          0.90                 0.00  0.43  0.70 9264.16 15031.32 21335.12
# 4          0.73                 0.00  0.68  0.82 2042.08  2465.64  3006.66
#
#    RadiusOfGyration  SpherocityIndex
# 0              2.86             0.65
# 1              3.73             0.25
# 2              4.06             0.26
# 3              5.69             0.26
# 4              2.91             0.73

# %%
X = df.drop(['Name','PubChem CID','SMILES','Observed logFM','Predicted logFM'],axis=1)
X.head()
# Out:
#    Asphericity  Eccentricity  InertialShapeFactor  NPR1  NPR2    PMI1  \
# 0         0.12          0.85                 0.00  0.53  0.84 1547.95
# 1         0.36          0.95                 0.00  0.30  0.74 1310.39
# 2         0.18          0.87                 0.00  0.49  0.64 3254.02
# 3         0.21          0.90                 0.00  0.43  0.70 9264.16
# 4         0.05          0.73                 0.00  0.68  0.82 2042.08
#
#       PMI2     PMI3  RadiusOfGyration  SpherocityIndex
# 0  2465.69  2937.81              2.86             0.65
# 1  3209.34  4343.41              3.73             0.25
# 2  4267.07  6666.09              4.06             0.26
# 3 15031.32 21335.12              5.69             0.26
# 4  2465.64  3006.66              2.91             0.73

# %%
from sklearn import preprocessing
sscaler = preprocessing.StandardScaler()
X = sscaler.fit_transform(X)

# %% [markdown]
# ## Split data into train and test

# %%
TRAIN = 41

# %%
X_train = X[:TRAIN]
X_test = X[TRAIN:]

# %%
y = df['Observed logFM']
y = np.array(y)
y_train = y[:TRAIN]
y_test = y[TRAIN:]

# %% [markdown]
# ## Leave One Out Cross Validation

# %%
import optuna
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import LeaveOneOut
loo = LeaveOneOut()

# %%
def LOOCV(reg):
    rmse_min = np.inf
    for train_index, test_index in loo.split(X_train):
        loo_x_train, loo_x_test = X_train[train_index], X_train[test_index]
        loo_y_train, loo_y_test = y_train[train_index], y_train[test_index]
        reg.fit(loo_x_train,loo_y_train)
        result = reg.predict(X_train)
        rmse = mean_squared_error(y_train, result,squared=False)
        if rmse < rmse_min:
            rmse_min = rmse     
            best_model = reg
    return best_model

# %%
def True_Pred_map(y_pred, filename):
    if y_pred.size == TRAIN:
        y_pred_author = df['Predicted logFM'][:TRAIN]
        y_true = y_train
    else:
        y_pred_author = df['Predicted logFM'][TRAIN:]
        y_true = y_test
    RMSE = mean_squared_error(y_true,y_pred,squared=False)
    R2 = r2_score(y_true, y_pred)
    RMSE_author = mean_squared_error(y_true,y_pred_author,squared=False)
    R2_author = r2_score(y_true, y_pred_author)
    plt.figure(figsize=(8,8))
    ax = plt.subplot(111)
    ax.scatter(y_true, y_pred,label='Prediction')
    ax.scatter(y_true, y_pred_author,label='Author\'s Prediction')
    ax.set_xlabel('Observed logFM', fontsize=15)
    ax.set_ylabel('Predicted logFM', fontsize=15)
    y_true = pd.Series(y_true)
    y_pred = pd.Series(y_pred)
    pred_df = pd.concat([y_true,y_pred],axis=1)
    ax.set_xlim(pred_df.min().min()-0.1 , pred_df.max().max()+0.1)
    ax.set_ylim(pred_df.min().min()-0.1 , pred_df.max().max()+0.1)
    x = np.linspace(pred_df.min().min()-0.1, pred_df.max().max()+0.1, 2)
    y = x
    ax.plot(x,y,'-', color="tab:red")
    plt.text(0.05, 0.95, 'RMSE = {}'.format(str(round(RMSE, 5))), transform=ax.transAxes, fontsize=12,color="tab:blue")
    plt.text(0.05, 0.9, 'Q^2 = {}'.format(str(round(R2, 5))), transform=ax.transAxes, fontsize=12,color="tab:blue")
    plt.text(0.05, 0.85, 'RMSE = {}'.format(str(round(RMSE_author, 5))), transform=ax.transAxes, fontsize=12,color="tab:orange")
    plt.text(0.05, 0.8, 'Q^2 = {}'.format(str(round(R2_author, 5))), transform=ax.transAxes, fontsize=12,color="tab:orange")
    plt.legend(loc="lower right")
    if y_pred.size == TRAIN:
        plt.title("3D Descriptor "+filename+" (train data)",fontsize=15)
        plt.savefig("./output/3d_desc_"+filename+"_train.png",dpi=300)
    else:
        plt.title("3D Descriptor "+filename+" (test data)",fontsize=15)
        plt.savefig("./output/3d_desc_"+filename+"_test.png",dpi=300)

    y_pred = pd.Series(y_pred,name="Predicted logFM")
    y_true = pd.Series(y_true,name="Observed logFM")
    y_pred_author = pd.Series(y_pred_author,name="Author\'s Prediction").reset_index(drop=True)
    if y_pred.size == TRAIN:
        name = df['Name'][:TRAIN].reset_index(drop=True)
        pubchem_cid = df['PubChem CID'][:TRAIN].reset_index(drop=True)
    else:
        name = df['Name'][TRAIN:].reset_index(drop=True)
        pubchem_cid = df['PubChem CID'][TRAIN:].reset_index(drop=True)
    df_comp = pd.concat([name,pubchem_cid,y_true,y_pred,y_pred_author],axis=1)
    if y_pred.size == TRAIN:
        df_comp.to_csv("./output/3d_desc_"+filename+"_train.csv",float_format='%.2f',index=False)
    else:
        df_comp.to_csv("./output/3d_desc_"+filename+"_test.csv",float_format='%.2f',index=False)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg = LOOCV(reg)

y_pred = reg.predict(X_train)
rmse_train = mean_squared_error(y_train,y_pred,squared=False)
r2_train = r2_score(y_train,y_pred)

# %%
True_Pred_map(y_pred,"LinearRegression")

# %%
y_pred = reg.predict(X_test)
rmse_test = mean_squared_error(y_test,y_pred,squared=False)
r2_test = r2_score(y_test,y_pred)

# %%
True_Pred_map(y_pred,"LinearRegression")

# %%
print("RMSE diff:", abs(rmse_train - rmse_test))
print("R2 diff:", abs(r2_train - r2_test))
# Out:
# RMSE diff: 0.157275878225589
# R2 diff: 0.7080411482236888

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge

def objective(trial):
    alpha = trial.suggest_loguniform("alpha", 1e0, 1e2)
    reg = Ridge(alpha=alpha,random_state=0)
    reg = LOOCV(reg)
    y_pred = reg.predict(X_train)
    return 1 - r2_score(y_train,y_pred)

study = optuna.create_study()
study.optimize(objective, n_trials=100)

print(study.best_params)
print(study.best_value)
print(study.best_trial)
# Out:
# [I 2020-10-27 10:42:29,534] A new study created in memory with name: no-name-b6fe1bb6-d694-46ce-addb-718a2a0d3b10
# [I 2020-10-27 10:42:29,593] Trial 0 finished with value: 0.6138480345499369 and parameters: {'alpha': 14.267085316473178}. Best is trial 0 with value: 0.6138480345499369.
. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,003] Trial 80 finished with value: 0.5896380459680196 and parameters: {'alpha': 5.493491696101605}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,054] Trial 81 finished with value: 0.5399422030799551 and parameters: {'alpha': 1.0299475449081894}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,103] Trial 82 finished with value: 0.5456158126362575 and parameters: {'alpha': 1.2739821867064813}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,158] Trial 83 finished with value: 0.539350461488299 and parameters: {'alpha': 1.0062637728206423}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,206] Trial 84 finished with value: 0.6007005194209851 and parameters: {'alpha': 8.32539762326289}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,257] Trial 85 finished with value: 0.5420248707635374 and parameters: {'alpha': 1.115854576041874}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,315] Trial 86 finished with value: 0.5496793857526169 and parameters: {'alpha': 1.4700411390516863}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,377] Trial 87 finished with value: 0.5454797213405541 and parameters: {'alpha': 1.2677435028280009}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,436] Trial 88 finished with value: 0.5393258926852841 and parameters: {'alpha': 1.005287170103275}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,492] Trial 89 finished with value: 0.5421070382319241 and parameters: {'alpha': 1.1193278006044014}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,542] Trial 90 finished with value: 0.5560156841334353 and parameters: {'alpha': 1.8189541638586642}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,584] Trial 91 finished with value: 0.5398793579080473 and parameters: {'alpha': 1.0274173681688803}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,634] Trial 92 finished with value: 0.544432564877861 and parameters: {'alpha': 1.2204059952702029}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,684] Trial 93 finished with value: 0.5477293846649008 and parameters: {'alpha': 1.3735313694266207}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,745] Trial 94 finished with value: 0.6472201628712124 and parameters: {'alpha': 42.478325228666996}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,804] Trial 95 finished with value: 0.5394262230377083 and parameters: {'alpha': 1.009278634789856}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,855] Trial 96 finished with value: 0.5515126819132605 and parameters: {'alpha': 1.5651684540984128}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,929] Trial 97 finished with value: 0.5393087301585303 and parameters: {'alpha': 1.0046052811414952}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:33,993] Trial 98 finished with value: 0.5429903839737699 and parameters: {'alpha': 1.1570831223195197}. Best is trial 79 with value: 0.5392070280100087.
# [I 2020-10-27 10:42:34,052] Trial 99 finished with value: 0.5618217558253932 and parameters: {'alpha': 2.1960582286420745}. Best is trial 79 with value: 0.5392070280100087.
# {'alpha': 1.000569858895676}
# 0.5392070280100087
# FrozenTrial(number=79, value=0.5392070280100087, datetime_start=datetime.datetime(2020, 10, 27, 10, 42, 32, 881625), datetime_complete=datetime.datetime(2020, 10, 27, 10, 42, 32, 957714), params={'alpha': 1.000569858895676}, distributions={'alpha': LogUniformDistribution(high=100.0, low=1.0)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=79, state=TrialState.COMPLETE)

# %%
reg = Ridge(alpha=study.best_params['alpha'],random_state=0)
reg = LOOCV(reg)

y_pred = reg.predict(X_train)
rmse_train = mean_squared_error(y_train,y_pred,squared=False)
r2_train = r2_score(y_train,y_pred)

# %%
True_Pred_map(y_pred,"Ridge")

# %%
y_pred = reg.predict(X_test)
rmse_test = mean_squared_error(y_test,y_pred,squared=False)
r2_test = r2_score(y_test,y_pred)

# %%
True_Pred_map(y_pred,"Ridge")

# %%
print("RMSE diff:", abs(rmse_train - rmse_test))
print("R2 diff:", abs(r2_train - r2_test))
# Out:
# RMSE diff: 0.07324979807088486
# R2 diff: 0.2574529778186315

# %% [markdown]
# ### Support Vector Regression

# %%
from sklearn.svm import SVR

def objective(trial):
    svr_c = trial.suggest_loguniform('svr_c', 1e0, 1e2)
    epsilon = trial.suggest_loguniform('epsilon', 1e-1, 1e1)
    reg = SVR(C=svr_c, epsilon=epsilon)
    reg = LOOCV(reg)
    y_pred = reg.predict(X_train)
    return 1 - r2_score(y_train,y_pred)

study = optuna.create_study()
study.optimize(objective, n_trials=100)

print(study.best_params)
print(study.best_value)
print(study.best_trial)
# Out:
# .
# [I 2020-10-27 10:42:37,336] Trial 11 finished with value: 0.07530382823589266 and parameters: {'svr_c': 89.29022884230818, 'epsilon': 0.10395417284187544}. Best is trial 11 with value: 0.07530382823589266.
# [I 2020-10-27 10:42:37,399] Trial 12 finished with value: 0.08852858241919082 and parameters: {'svr_c': 97.6922576239683, 'epsilon': 0.1140327393973162}. Best is trial 11 with value: 0.07530382823589266.
# [I 2020-10-27 10:42:37,449] Trial 13 finished with value: 0.34244299947381474 and parameters: {'svr_c': 80.04706194730302, 'epsilon': 0.2689332012403431}. Best is trial 11 with value: 0.07530382823589266.
# [I 2020-10-27 10:42:37,520] Trial 14 finished with value: 0.07196729148848235 and parameters: {'svr_c': 94.35445120262881, 'epsilon': 0.10069378794876065}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,561] Trial 15 finished with value: 1.1551099661167674 and parameters: {'svr_c': 49.78816952484854, 'epsilon': 2.5007625079012956}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,604] Trial 16 finished with value: 0.5570063314712586 and parameters: {'svr_c': 17.279634269589003, 'epsilon': 0.3604737674780109}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,645] Trial 17 finished with value: 1.1551099661167679 and parameters: {'svr_c': 8.157472207662634, 'epsilon': 0.7073984395998373}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,689] Trial 18 finished with value: 1.1551099661167674 and parameters: {'svr_c': 50.29404913258067, 'epsilon': 3.108141329187147}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,752] Trial 19 finished with value: 0.09713800217117763 and parameters: {'svr_c': 29.00526632827698, 'epsilon': 0.10081922059269043}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,797] Trial 20 finished with value: 0.2908899377859536 and parameters: {'svr_c': 3.6455443280332265, 'epsilon': 0.18709058548604066}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,860] Trial 21 finished with value: 0.07396332128036975 and parameters: {'svr_c': 97.79946529260093, 'epsilon': 0.10272258658219074}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,942] Trial 22 finished with value: 0.074605409209892 and parameters: {'svr_c': 98.26358750697209, 'epsilon': 0.10330094452766801}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:37,998] Trial 23 finished with value: 0.3666507806539361 and parameters: {'svr_c': 60.97725859570237, 'epsilon': 0.28303997660424324}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,069] Trial 24 finished with value: 0.09363585082662362 and parameters: {'svr_c': 37.03469421391478, 'epsilon': 0.1005397515966924}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,134] Trial 25 finished with value: 0.2042475072303569 and parameters: {'svr_c': 94.65654506237819, 'epsilon': 0.18035565736197204}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,199] Trial 26 finished with value: 0.1661174531075753 and parameters: {'svr_c': 19.926837027997635, 'epsilon': 0.14831181791880296}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,253] Trial 27 finished with value: 0.32158960503590084 and parameters: {'svr_c': 65.23722492861478, 'epsilon': 0.25672315519730293}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,298] Trial 28 finished with value: 0.8384089662399882 and parameters: {'svr_c': 46.41225412827891, 'epsilon': 0.44612895134165864}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,339] Trial 29 finished with value: 1.1551099661167679 and parameters: {'svr_c': 11.27325538205864, 'epsilon': 0.6596795885355231}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,402] Trial 30 finished with value: 0.13276894165177822 and parameters: {'svr_c': 67.15505507419368, 'epsilon': 0.14356845301094392}. Best is trial 14 with value: 0.07196729148848235.
# [I 2020-10-27 10:42:38,475] Trial 31 finished with value: 0.07158340695747178 and parameters: {'svr_c': 85.67157452782145, 'epsilon': 0.10008951435288412}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,544] Trial 32 finished with value: 0.07746828790765659 and parameters: {'svr_c': 93.59387080292737, 'epsilon': 0.10591631584609863}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,599] Trial 33 finished with value: 0.23634247896474847 and parameters: {'svr_c': 35.1584928814212, 'epsilon': 0.1981520351474676}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,650] Trial 34 finished with value: 0.2828923969610564 and parameters: {'svr_c': 59.884154133206145, 'epsilon': 0.23093087820793498}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,691] Trial 35 finished with value: 1.1551099661167679 and parameters: {'svr_c': 26.380586445526887, 'epsilon': 9.50308793847975}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,750] Trial 36 finished with value: 0.11522067984450657 and parameters: {'svr_c': 97.7569491951404, 'epsilon': 0.13296024644378315}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,811] Trial 37 finished with value: 0.11819268783079162 and parameters: {'svr_c': 37.81311985638171, 'epsilon': 0.12807356161972225}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,856] Trial 38 finished with value: 0.4669241753136282 and parameters: {'svr_c': 3.937737414651749, 'epsilon': 0.31955788091026427}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,911] Trial 39 finished with value: 0.2111532885735572 and parameters: {'svr_c': 77.23329046233125, 'epsilon': 0.18385205624723777}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:38,949] Trial 40 finished with value: 0.23788430423548212 and parameters: {'svr_c': 5.2578197061790455, 'epsilon': 0.15545057227676318}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,008] Trial 41 finished with value: 0.07211495696725223 and parameters: {'svr_c': 83.34811522382029, 'epsilon': 0.10085745251471533}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,065] Trial 42 finished with value: 0.08102463988940967 and parameters: {'svr_c': 99.34389612604168, 'epsilon': 0.10876819781305466}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,141] Trial 43 finished with value: 0.07514023133383763 and parameters: {'svr_c': 58.128291949955255, 'epsilon': 0.1013322136118466}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,193] Trial 44 finished with value: 0.1008399110465974 and parameters: {'svr_c': 76.10131997420746, 'epsilon': 0.12340732007794038}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,239] Trial 45 finished with value: 0.2609637809958173 and parameters: {'svr_c': 41.45231860525496, 'epsilon': 0.2164712961313514}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,288] Trial 46 finished with value: 0.15523131204571317 and parameters: {'svr_c': 73.98176709969317, 'epsilon': 0.15588752549593657}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,328] Trial 47 finished with value: 0.3250570162569626 and parameters: {'svr_c': 2.1907466439837795, 'epsilon': 0.12925983869001756}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,381] Trial 48 finished with value: 0.09162665024023464 and parameters: {'svr_c': 99.97643592191282, 'epsilon': 0.11619216106801943}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,413] Trial 49 finished with value: 1.1551099661167674 and parameters: {'svr_c': 53.079099067743975, 'epsilon': 2.213695296133143}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39,449] Trial 50 finished with value: 1.1551099661167679 and parameters: {'svr_c': 82.5333452717053, 'epsilon': 0.9125854032421222}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:39
. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,032] Trial 75 finished with value: 0.0735229070103216 and parameters: {'svr_c': 74.79101762664575, 'epsilon': 0.10222736772515773}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,085] Trial 76 finished with value: 0.10249804739990165 and parameters: {'svr_c': 41.61113715449127, 'epsilon': 0.11546672890269866}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,136] Trial 77 finished with value: 0.14358479223943754 and parameters: {'svr_c': 98.04912912707657, 'epsilon': 0.14967315399701955}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,193] Trial 78 finished with value: 0.08020505723385929 and parameters: {'svr_c': 52.34067514990352, 'epsilon': 0.1009501098166725}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,242] Trial 79 finished with value: 0.22731284184829792 and parameters: {'svr_c': 74.17708137317335, 'epsilon': 0.19189818489091273}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,299] Trial 80 finished with value: 0.07165717161622598 and parameters: {'svr_c': 89.78292882237528, 'epsilon': 0.10034250719198795}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,354] Trial 81 finished with value: 0.10767870725331208 and parameters: {'svr_c': 93.13950387249375, 'epsilon': 0.12808514651913894}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,406] Trial 82 finished with value: 0.08972154166102775 and parameters: {'svr_c': 63.1477708759046, 'epsilon': 0.11474739656078659}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,441] Trial 83 finished with value: 0.9384417751258615 and parameters: {'svr_c': 80.84558575346564, 'epsilon': 0.46973395829244186}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,501] Trial 84 finished with value: 0.07336770593479669 and parameters: {'svr_c': 88.91271331514916, 'epsilon': 0.10217980141567051}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,563] Trial 85 finished with value: 0.1146482285157775 and parameters: {'svr_c': 58.262740790973204, 'epsilon': 0.13261886857608426}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,605] Trial 86 finished with value: 1.1551099661167679 and parameters: {'svr_c': 72.74104267830258, 'epsilon': 1.5741843345033575}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,663] Trial 87 finished with value: 0.1404938949598189 and parameters: {'svr_c': 89.69939752492499, 'epsilon': 0.14798450570702718}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,722] Trial 88 finished with value: 0.08589895876182252 and parameters: {'svr_c': 47.22213978491026, 'epsilon': 0.10019623958212522}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,777] Trial 89 finished with value: 0.08460369058124306 and parameters: {'svr_c': 98.8428384883244, 'epsilon': 0.11142533326210778}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,826] Trial 90 finished with value: 0.12756388883947822 and parameters: {'svr_c': 31.256475561890415, 'epsilon': 0.12685693847499682}. Best is trial 31 with value: 0.07158340695747178.
# [I 2020-10-27 10:42:41,883] Trial 91 finished with value: 0.07155427807929615 and parameters: {'svr_c': 81.31038162146851, 'epsilon': 0.10012023024620167}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:41,940] Trial 92 finished with value: 0.07164886235246593 and parameters: {'svr_c': 78.70971485489076, 'epsilon': 0.10016814833190808}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:41,991] Trial 93 finished with value: 0.08771253351634778 and parameters: {'svr_c': 79.186014205736, 'epsilon': 0.11350305459013746}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:42,047] Trial 94 finished with value: 0.11799088959224235 and parameters: {'svr_c': 71.47246789119968, 'epsilon': 0.13480193983160285}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:42,097] Trial 95 finished with value: 0.17223089339209208 and parameters: {'svr_c': 55.4139121660836, 'epsilon': 0.16491305063119455}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:42,157] Trial 96 finished with value: 0.37111983240161905 and parameters: {'svr_c': 1.0464326769573529, 'epsilon': 0.11057776943298082}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:42,214] Trial 97 finished with value: 0.10146704016075381 and parameters: {'svr_c': 79.54068537699251, 'epsilon': 0.12386356726052473}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:42,265] Trial 98 finished with value: 0.13757864327619906 and parameters: {'svr_c': 61.726278338575796, 'epsilon': 0.14629511615276206}. Best is trial 91 with value: 0.07155427807929615.
# [I 2020-10-27 10:42:42,324] Trial 99 finished with value: 0.07243001746271882 and parameters: {'svr_c': 90.70412824808825, 'epsilon': 0.10117064933549623}. Best is trial 91 with value: 0.07155427807929615.
# {'svr_c': 81.31038162146851, 'epsilon': 0.10012023024620167}
# 0.07155427807929615
# FrozenTrial(number=91, value=0.07155427807929615, datetime_start=datetime.datetime(2020, 10, 27, 10, 42, 41, 827397), datetime_complete=datetime.datetime(2020, 10, 27, 10, 42, 41, 883283), params={'svr_c': 81.31038162146851, 'epsilon': 0.10012023024620167}, distributions={'svr_c': LogUniformDistribution(high=100.0, low=1.0), 'epsilon': LogUniformDistribution(high=10.0, low=0.1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=91, state=TrialState.COMPLETE)

# %%
reg = SVR(C=study.best_params['svr_c'],epsilon=study.best_params['epsilon'])
reg = LOOCV(reg)

y_pred = reg.predict(X_train)
rmse_train = mean_squared_error(y_train,y_pred,squared=False)
r2_train = r2_score(y_train,y_pred)

# %%
True_Pred_map(y_pred,"SVR")

# %%
y_pred = reg.predict(X_test)
rmse_test = mean_squared_error(y_test,y_pred,squared=False)
r2_test = r2_score(y_test,y_pred)

# %%
True_Pred_map(y_pred,"SVR")

# %%
print("RMSE diff:", abs(rmse_train - rmse_test))
print("R2 diff:", abs(r2_train - r2_test))
# Out:
# RMSE diff: 0.2809549409653855
# R2 diff: 0.9851913643455996

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

def objective(trial):
    min_samples_split = trial.suggest_int("min_samples_split", 2, 16)
    max_leaf_nodes = int(trial.suggest_discrete_uniform("max_leaf_nodes", 4, 64, 4))
    reg = RandomForestRegressor(min_samples_split=min_samples_split,max_leaf_nodes=max_leaf_nodes,criterion="mse",random_state=0)
    reg = LOOCV(reg)
    y_pred = reg.predict(X_train)
    return 1 - r2_score(y_train,y_pred)

study = optuna.create_study()
study.optimize(objective, n_trials=10)

print(study.best_params)
print(study.best_value)
print(study.best_trial)
# Out:
# [I 2020-10-27 10:42:44,154] A new study created in memory with name: no-name-bea57a8b-9002-46ba-868e-755a451e7bcb
# [I 2020-10-27 10:42:49,616] Trial 0 finished with value: 0.4469710667193487 and parameters: {'min_samples_split': 14, 'max_leaf_nodes': 20.0}. Best is trial 0 with value: 0.4469710667193487.
# [I 2020-10-27 10:42:55,389] Trial 1 finished with value: 0.16538311081328683 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 60.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:01,047] Trial 2 finished with value: 0.30109667224003134 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 56.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:06,449] Trial 3 finished with value: 0.252896080588487 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 12.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:11,591] Trial 4 finished with value: 0.32827895015120356 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 20.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:16,893] Trial 5 finished with value: 0.19727402504809965 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 24.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:22,069] Trial 6 finished with value: 0.252896080588487 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 32.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:27,362] Trial 7 finished with value: 0.2817605372323633 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 52.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:32,559] Trial 8 finished with value: 0.252896080588487 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 20.0}. Best is trial 1 with value: 0.16538311081328683.
# [I 2020-10-27 10:43:37,811] Trial 9 finished with value: 0.4469710667193487 and parameters: {'min_samples_split': 14, 'max_leaf_nodes': 60.0}. Best is trial 1 with value: 0.16538311081328683.
# {'min_samples_split': 3, 'max_leaf_nodes': 60.0}
# 0.16538311081328683
# FrozenTrial(number=1, value=0.16538311081328683, datetime_start=datetime.datetime(2020, 10, 27, 10, 42, 49, 617210), datetime_complete=datetime.datetime(2020, 10, 27, 10, 42, 55, 389612), params={'min_samples_split': 3, 'max_leaf_nodes': 60.0}, distributions={'min_samples_split': IntUniformDistribution(high=16, low=2, step=1), 'max_leaf_nodes': DiscreteUniformDistribution(high=64, low=4, q=4)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=1, state=TrialState.COMPLETE)

# %%
reg = RandomForestRegressor(min_samples_split=study.best_params['min_samples_split'],max_leaf_nodes=int(study.best_params['max_leaf_nodes']),criterion="mse",random_state=0)
reg = LOOCV(reg)

y_pred = reg.predict(X_train)
rmse_train = mean_squared_error(y_train,y_pred,squared=False)
r2_train = r2_score(y_train,y_pred)

# %%
True_Pred_map(y_pred,"RandomForest")

# %%
y_pred = reg.predict(X_test)
rmse_test = mean_squared_error(y_test,y_pred,squared=False)
r2_test = r2_score(y_test,y_pred)

# %%
True_Pred_map(y_pred,"RandomForest")

# %%
print("RMSE diff:", abs(rmse_train - rmse_test))
print("R2 diff:", abs(r2_train - r2_test))
# Out:
# RMSE diff: 0.18513530032727274
# R2 diff: 0.6337093533569449

# %% [markdown]
# ### LightGBM

# %%
import optuna.integration.lightgbm as lgb_o
from sklearn.model_selection import train_test_split

rmse_min = np.inf
for train_index, test_index in loo.split(X_train):
    loo_x_train, loo_x_test = X_train[train_index], X_train[test_index]
    loo_y_train, loo_y_test = y_train[train_index], y_train[test_index]
    lgb_train = lgb_o.Dataset(loo_x_train, loo_y_train)
    lgb_val = lgb_o.Dataset(loo_x_test, loo_y_test)

    params = {'objective': 'regression',
            'metric': 'rmse',
            'verbose': -1} 

    gbm_o = lgb_o.train(params,
                        lgb_train,
                        valid_sets=lgb_val,
                        num_boost_round=10000,
                        early_stopping_rounds=100,
                        verbose_eval=200,)
    y_pred = gbm_o.predict(X_train,num_iteration=gbm_o.best_iteration)
    rmse = mean_squared_error(y_train, y_pred,squared=False)
    if rmse < rmse_min:
        rmse_min = rmse     
        best_model = gbm_o
gbm_o = best_model
# Out:
# core: 0.521500: 100%|##########| 20/20 [00:02<00:00,  7.27it/s][I 2020-10-27 10:57:46,603] Trial 26 finished with value: 0.5215000033471733 and parameters: {'num_leaves': 96}. Best is trial 7 with value: 0.5215000033471733.
# num_leaves, val_score: 0.521500: 100%|##########| 20/20 [00:02<00:00,  6.82it/s]
# bagging, val_score: 0.521500:   0%|          | 0/10 [00:00<?, ?it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.521500:  10%|#         | 1/10 [00:00<00:02,  3.39it/s][I 2020-10-27 10:57:46,906] Trial 27 finished with value: 0.6277146491347592 and parameters: {'bagging_fraction': 0.9022071962706105, 'bagging_freq': 7}. Best is trial 27 with value: 0.6277146491347592.
# bagging, val_score: 0.521500:  20%|##        | 2/10 [00:00<00:01,  4.15it/s][I 2020-10-27 10:57:47,020] Trial 28 finished with value: 0.8369999995455146 and parameters: {'bagging_fraction': 0.4358050370073061, 'bagging_freq': 1}. Best is trial 27 with value: 0.6277146491347592.
# bagging, val_score: 0.521500:  20%|##        | 2/10 [00:00<00:01,  4.15it/s]Early stopping, best iteration is:
# [92]	valid_0's rmse: 0.627715
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.521500:  30%|###       | 3/10 [00:00<00:01,  4.85it/s][I 2020-10-27 10:57:47,145] Trial 29 finished with value: 0.8369999995455146 and parameters: {'bagging_fraction': 0.45052490642841153, 'bagging_freq': 4}. Best is trial 27 with value: 0.6277146491347592.
# bagging, val_score: 0.521500:  40%|####      | 4/10 [00:00<00:01,  5.11it/s][I 2020-10-27 10:57:47,316] Trial 30 finished with value: 0.5215000033471733 and parameters: {'bagging_fraction': 0.9937720839274883, 'bagging_freq': 7}. Best is trial 30 with value: 0.5215000033471733.
# bagging, val_score: 0.521500:  40%|####      | 4/10 [00:00<00:01,  5.11it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.521500:  50%|#####     | 5/10 [00:00<00:00,  5.95it/s][I 2020-10-27 10:57:47,420] Trial 31 finished with value: 0.8369999995455146 and parameters: {'bagging_fraction': 0.6957188657428796, 'bagging_freq': 1}. Best is trial 30 with value: 0.5215000033471733.
# bagging, val_score: 0.521500:  60%|######    | 6/10 [00:00<00:00,  6.37it/s][I 2020-10-27 10:57:47,551] Trial 32 finished with value: 0.8369999995455146 and parameters: {'bagging_fraction': 0.6881546958997734, 'bagging_freq': 4}. Best is trial 30 with value: 0.5215000033471733.
# bagging, val_score: 0.521500:  60%|######    | 6/10 [00:00<00:00,  6.37it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.521500:  70%|#######   | 7/10 [00:01<00:00,  6.11it/s][I 2020-10-27 10:57:47,730] Trial 33 finished with value: 0.5215000033471733 and parameters: {'bagging_fraction': 0.9817956374351205, 'bagging_freq': 7}. Best is trial 30 with value: 0.5215000033471733.
# bagging, val_score: 0.521500:  80%|########  | 8/10 [00:01<00:00,  6.06it/s][I 2020-10-27 10:57:47,898] Trial 34 finished with value: 0.8369999995455146 and parameters: {'bagging_fraction': 0.8262932303704121, 'bagging_freq': 6}. Best is trial 30 with value: 0.5215000033471733.
# bagging, val_score: 0.521500:  80%|########  | 8/10 [00:01<00:00,  6.06it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# bagging, val_score: 0.521500:  90%|######### | 9/10 [00:01<00:00,  6.56it/s][I 2020-10-27 10:57:48,022] Trial 35 finished with value: 0.8369999995455146 and parameters: {'bagging_fraction': 0.5748299469112993, 'bagging_freq': 5}. Best is trial 30 with value: 0.5215000033471733.
# bagging, val_score: 0.521500: 100%|##########| 10/10 [00:01<00:00,  6.79it/s][I 2020-10-27 10:57:48,157] Trial 36 finished with value: 0.5215000033471733 and parameters: {'bagging_fraction': 0.9929446676793219, 'bagging_freq': 7}. Best is trial 30 with value: 0.5215000033471733.
# bagging, val_score: 0.521500: 100%|##########| 10/10 [00:01<00:00,  6.44it/s]
# feature_fraction_stage2, val_score: 0.521500:   0%|          | 0/6 [00:00<?, ?it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 0.521500:  17%|#6        | 1/6 [00:00<00:00,  5.74it/s][I 2020-10-27 10:57:48,341] Trial 37 finished with value: 0.5215000033471733 and parameters: {'feature_fraction': 0.9159999999999999}. Best is trial 37 with value: 0.5215000033471733.
# feature_fraction_stage2, val_score: 0.521500:  33%|###3      | 2/6 [00:00<00:00,  6.02it/s][I 2020-10-27 10:57:48,487] Trial 38 finished with value: 0.5215000033471733 and parameters: {'feature_fraction': 0.82}. Best is trial 37 with value: 0.5215000033471733.
# feature_fraction_stage2, val_score: 0.521500:  33%|###3      | 2/6 [00:00<00:00,  6.02it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 0.521500:  50%|#####     | 3/6 [00:00<00:00,  6.24it/s][I 2020-10-27 10:57:48,634] Trial 39 finished with value: 0.5215000033471733 and parameters: {'feature_fraction': 0.852}. Best is trial 37 with value: 0.5215000033471733.
# feature_fraction_stage2, val_score: 0.521500:  67%|######6   | 4/6 [00:00<00:00,  6.81it/s][I 2020-10-27 10:57:48,749] Trial 40 finished with value: 0.5215000033471733 and parameters: {'feature_fraction': 0.9799999999999999}. Best is trial 37 with value: 0.5215000033471733.
# feature_fraction_stage2, val_score: 0.521500:  67%|######6   | 4/6 [00:00<00:00,  6.81it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# feature_fraction_stage2, val_score: 0.521500:  83%|########3 | 5/6 [00:00<00:00,  6.85it/s][I 2020-10-27 10:57:48,893] Trial 41 finished with value: 0.5215000033471733 and parameters: {'feature_fraction': 0.948}. Best is trial 37 with value: 0.5215000033471733.
# feature_fraction_stage2, val_score: 0.521500: 100%|##########| 6/6 [00:00<00:00,  7.13it/s][I 2020-10-27 10:57:49,020] Trial 42 finished with value: 0.5215000033471733 and parameters: {'feature_fraction': 0.8839999999999999}. Best is trial 37 with value: 0.5215000033471733.
# feature_fraction_stage2, val_score: 0.521500: 100%|##########| 6/6 [00:00<00:00,  6.99it/s]
# regularization_factors, val_score: 0.521500:   0%|          | 0/20 [00:00<?, ?it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.5215
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.521493:   5%|5         | 1/20 [00:00<00:02,  6.44it/s][I 2020-10-27 10:57:49,186] Trial 43 finished with value: 0.5214931660366098 and parameters: {'lambda_l1': 0.0013667437033382515, 'lambda_l2': 5.529134051548054e-06}. Best is trial 43 with value: 0.5214931660366098.
# regularization_factors, val_score: 0.521481:  10%|#         | 2/20 [00:00<00:02,  6.55it/s][I 2020-10-27 10:57:49,333] Trial 44 finished with value: 0.5214813718333613 and parameters: {'lambda_l1': 0.00372601505212528, 'lambda_l2': 2.216332534702898e-06}. Best is trial 44 with value: 0.5214813718333613.
# regularization_factors, val_score: 0.521481:  10%|#         | 2/20 [00:00<00:02,  6.55it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521493
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521481
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.521481:  15%|#5        | 3/20 [00:00<00:02,  6.59it/s][I 2020-10-27 10:57:49,483] Trial 45 finished with value: 0.5214847736534198 and parameters: {'lambda_l1': 0.0030454714704797456, 'lambda_l2': 3.5986791612969804e-06}. Best is trial 44 with value: 0.5214813718333613.
# regularization_factors, val_score: 0.521481:  20%|##        | 4/20 [00:00<00:02,  6.84it/s][I 2020-10-27 10:57:49,615] Trial 46 finished with value: 0.521485424503468 and parameters: {'lambda_l1': 0.00291526600392177, 'lambda_l2': 3.871550549316368e-06}. Best is trial 44 with value: 0.5214813718333613.
# regularization_factors, val_score: 0.521481:  20%|##        | 4/20 [00:00<00:02,  6.84it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521485
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521485
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.521481:  25%|##5       | 5/20 [00:00<00:02,  6.47it/s][I 2020-10-27 10:57:49,789] Trial 47 finished with value: 0.521486850292443 and parameters: {'lambda_l1': 0.002630209477736766, 'lambda_l2': 3.09134572397833e-06}. Best is trial 44 with value: 0.5214813718333613.
# regularization_factors, val_score: 0.521481:  30%|###       | 6/20 [00:00<00:02,  6.66it/s][I 2020-10-27 10:57:49,929] Trial 48 finished with value: 0.5214890758869708 and parameters: {'lambda_l1': 0.0021850172823163656, 'lambda_l2': 3.6550585446056323e-06}. Best is trial 44 with value: 0.5214813718333613.
# regularization_factors, val_score: 0.521481:  30%|###       | 6/20 [00:00<00:02,  6.66it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521487
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521489
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.521480:  35%|###5      | 7/20 [00:01<00:02,  5.76it/s][I 2020-10-27 10:57:50,158] Trial 49 finished with value: 0.5214803605254725 and parameters: {'lambda_l1': 0.003928192284994795, 'lambda_l2': 2.8662937049875854e-06}. Best is trial 49 with value: 0.5214803605254725.
# regularization_factors, val_score: 0.521479:  40%|####      | 8/20 [00:01<00:01,  6.13it/s][I 2020-10-27 10:57:50,296] Trial 50 finished with value: 0.5214787220885145 and parameters: {'lambda_l1': 0.004255821350992048, 'lambda_l2': 3.316049779628403e-06}. Best is trial 50 with value: 0.5214787220885145.
# regularization_factors, val_score: 0.521479:  40%|####      | 8/20 [00:01<00:01,  6.13it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.52148
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521479
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.521479:  45%|####5     | 9/20 [00:01<00:01,  6.19it/s][I 2020-10-27 10:57:50,454] Trial 51 finished with value: 0.521479748626542 and parameters: {'lambda_l1': 0.004050675177606953, 'lambda_l2': 2.072064265017135e-06}. Best is trial 50 with value: 0.5214787220885145.
# regularization_factors, val_score: 0.521473:  50%|#####     | 10/20 [00:01<00:01,  6.56it/s][I 2020-10-27 10:57:50,585] Trial 52 finished with value: 0.5214728967633314 and parameters: {'lambda_l1': 0.005421046556981747, 'lambda_l2': 2.082892400756458e-06}. Best is trial 52 with value: 0.5214728967633314.
# regularization_factors, val_score: 0.521473:  50%|#####     | 10/20 [00:01<00:01,  6.56it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.52148
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521473
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.521452:  55%|#####5    | 11/20 [00:01<00:01,  6.42it/s][I 2020-10-27 10:57:50,749] Trial 53 finished with value: 0.521452350782009 and parameters: {'lambda_l1': 0.009530346854115242, 'lambda_l2': 1.2830009853045498e-06}. Best is trial 53 with value: 0.521452350782009.
# regularization_factors, val_score: 0.521219:  60%|######    | 12/20 [00:01<00:01,  6.71it/s][I 2020-10-27 10:57:50,882] Trial 54 finished with value: 0.5212192189403261 and parameters: {'lambda_l1': 0.05615682623122875, 'lambda_l2': 4.335033572891464e-07}. Best is trial 54 with value: 0.5212192189403261.
# regularization_factors, val_score: 0.521219:  60%|######    | 12/20 [00:01<00:01,  6.71it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521452
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.521219
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.521219:  65%|######5   | 13/20 [00:01<00:00,  7.16it/s][I 2020-10-27 10:57:51,000] Trial 55 finished with value: 0.8369999995455146 and parameters: {'lambda_l1': 4.639274644507255, 'lambda_l2': 1.377680931734401e-07}. Best is trial 54 with value: 0.5212192189403261.
# regularization_factors, val_score: 0.520471:  70%|#######   | 14/20 [00:02<00:00,  6.57it/s][I 2020-10-27 10:57:51,182] Trial 56 finished with value: 0.5204705751350511 and parameters: {'lambda_l1': 0.2058856375326724, 'lambda_l2': 4.0865052254655644e-08}. Best is trial 56 with value: 0.5204705751350511.
# regularization_factors, val_score: 0.520471:  70%|#######   | 14/20 [00:02<00:00,  6.57it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.520471
# regularization_factors, val_score: 0.520471:  75%|#######5  | 15/20 [00:02<00:00,  6.48it/s][I 2020-10-27 10:57:51,341] Trial 57 finished with value: 0.5207354346826816 and parameters: {'lambda_l1': 0.1529137314810643, 'lambda_l2': 1.1583597223747596e-08}. Best is trial 56 with value: 0.5204705751350511.
# regularization_factors, val_score: 0.520471:  75%|#######5  | 15/20 [00:02<00:00,  6.48it/s]Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.520735
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.519283:  80%|########  | 16/20 [00:02<00:00,  6.49it/s][I 2020-10-27 10:57:51,495] Trial 58 finished with value: 0.5192833405947428 and parameters: {'lambda_l1': 0.4433325481709813, 'lambda_l2': 2.146959156813266e-08}. Best is trial 58 with value: 0.5192833405947428.
# regularization_factors, val_score: 0.517733:  85%|########5 | 17/20 [00:02<00:00,  6.79it/s][I 2020-10-27 10:57:51,626] Trial 59 finished with value: 0.5177326599142416 and parameters: {'lambda_l1': 0.7534686850441801, 'lambda_l2': 1.670360384770639e-08}. Best is trial 59 with value: 0.5177326599142416.
# regularization_factors, val_score: 0.517733:  85%|########5 | 17/20 [00:02<00:00,  6.79it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.519283
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.517733
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.517733:  90%|######### | 18/20 [00:02<00:00,  6.69it/s][I 2020-10-27 10:57:51,780] Trial 60 finished with value: 0.5182876297345098 and parameters: {'lambda_l1': 0.642474721362567, 'lambda_l2': 1.1955340811363675e-08}. Best is trial 59 with value: 0.5177326599142416.
# regularization_factors, val_score: 0.515567:  95%|#########5| 19/20 [00:02<00:00,  7.08it/s][I 2020-10-27 10:57:51,902] Trial 61 finished with value: 0.5155672920111023 and parameters: {'lambda_l1': 1.1865422662784786, 'lambda_l2': 1.3240477350945887e-08}. Best is trial 61 with value: 0.5155672920111023.
# regularization_factors, val_score: 0.515567:  95%|#########5| 19/20 [00:02<00:00,  7.08it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.518288
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.515567
# Training until validation scores don't improve for 100 rounds
# regularization_factors, val_score: 0.515567: 100%|##########| 20/20 [00:03<00:00,  7.26it/s][I 2020-10-27 10:57:52,032] Trial 62 finished with value: 0.5182735291305529 and parameters: {'lambda_l1': 0.6452948422129475, 'lambda_l2': 1.1368752909988179e-08}. Best is trial 61 with value: 0.5155672920111023.
# regularization_factors, val_score: 0.515567: 100%|##########| 20/20 [00:03<00:00,  6.66it/s]
# min_data_in_leaf, val_score: 0.413680:  20%|##        | 1/5 [00:00<00:00,  6.76it/s][I 2020-10-27 10:57:52,188] Trial 63 finished with value: 0.4136800353387112 and parameters: {'min_child_samples': 10}. Best is trial 63 with value: 0.4136800353387112.
# min_data_in_leaf, val_score: 0.413680:  20%|##        | 1/5 [00:00<00:00,  6.76it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.518274
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's rmse: 0.41368
# Early stopping, best iteration is:
# [204]	valid_0's rmse: 0.41368
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 0.413680:  40%|####      | 2/5 [00:00<00:00,  7.02it/s][I 2020-10-27 10:57:52,317] Trial 64 finished with value: 0.8369999995455146 and parameters: {'min_child_samples': 50}. Best is trial 63 with value: 0.4136800353387112.
# min_data_in_leaf, val_score: 0.413680:  40%|####      | 2/5 [00:00<00:00,  7.02it/s][I 2020-10-27 10:57:52,392] Trial 65 finished with value: 0.8369999995455146 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.4136800353387112.
# min_data_in_leaf, val_score: 0.392514:  80%|########  | 4/5 [00:00<00:00,  7.91it/s][I 2020-10-27 10:57:52,495] Trial 66 finished with value: 0.39251397483614203 and parameters: {'min_child_samples': 5}. Best is trial 66 with value: 0.39251397483614203.
# min_data_in_leaf, val_score: 0.392514:  80%|########  | 4/5 [00:00<00:00,  7.91it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 0.392514
# Training until validation scores don't improve for 100 rounds
# min_data_in_leaf, val_score: 0.392514:  80%|########  | 4/5 [00:00<00:00,  7.91it/s][I 2020-10-27 10:57:52,566] Trial 67 finished with value: 0.8369999995455146 and parameters: {'min_child_samples': 100}. Best is trial 66 with value: 0.39251397483614203.
# min_data_in_leaf, val_score: 0.392514: 100%|##########| 5/5 [00:00<00:00,  9.44it/s]Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.837

# %%
y_pred = gbm_o.predict(X_train,num_iteration=gbm_o.best_iteration)

rmse_train = mean_squared_error(y_train,y_pred,squared=False)
r2_train = r2_score(y_train,y_pred)

# %%
True_Pred_map(y_pred,'LightGBM')

# %%
y_pred = gbm_o.predict(X_test,num_iteration=gbm_o.best_iteration)
rmse_test = mean_squared_error(y_test,y_pred,squared=False)
r2_test = r2_score(y_test,y_pred)

# %%
True_Pred_map(y_pred,'LightGBM')

# %%
print("RMSE diff:", abs(rmse_train - rmse_test))
print("R2 diff:", abs(r2_train - r2_test))
# Out:
# RMSE diff: 0.32295510514510295
# R2 diff: 0.8170547781912261
